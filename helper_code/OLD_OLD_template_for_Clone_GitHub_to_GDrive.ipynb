# %%
# Mount your personal Google Drive in Colab at "/content/drive"
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone github repository setup

# Add your desired path in which you will clone the repository
GDRIVE_PATH = "/content/drive/My Drive/Colab Notebooks/NRUHSE_2_Kaggle_Coursera/final"
# Enter your token here (get it from github.com/settings/tokens -- it should be unique to you)
GIT_TOKEN = "123456789"
GIT_USERNAME = "migai"
GIT_REPO = "Kag" 
REPO_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPO + ".git"
GDRIVE_REPO_PATH = GDRIVE_PATH + "/" + GIT_REPO
# Create empty folder to hold the cloned repo (if not done already)
# !mkdir "{GDRIVE_PATH}"    

# %cd "{GDRIVE_PATH}"
# Out:
# /content/drive/My Drive/Colab Notebooks/NRUHSE_2_Kaggle_Coursera/final

# %%
# !git pull "{REPO_PATH}"

# %%
# !git clone "{REPO_PATH}"
# Out:
# Cloning into 'Kag'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 154 (delta 25), reused 7 (delta 2), pack-reused 93
# Receiving objects: 100% (154/154), 14.45 MiB | 18.63 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# !git branch
# Out:
# * master
